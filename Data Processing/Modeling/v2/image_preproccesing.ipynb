# %%
import json

with open('all_labeled.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

filtered_data = []
for item in data:
    data_info = item.get('data', {})
    images = data_info.get('images')
    # Bỏ các sample có images là [""] hoặc images là None
    if images and not (len(images) == 1 and images[0] == ""):
        image_helpfulness = []
        for ann in item.get('annotations', []):
            for res in ann.get('result', []):
                if res.get('from_name') == 'Image_helpfulness':
                    choices = res.get('value', {}).get('choices', [])
                    for c in choices:
                        try:
                            image_helpfulness.append(int(c))
                        except:
                            pass
        new_item = {
            'images': images,
            'Image_helpfulness': image_helpfulness,
            'product_category': data_info.get('product_category'),
            'product_name': data_info.get('product_name'),
            'id': item.get('id'),  # Lấy id tổng của sample thay vì product_id
        }
        filtered_data.append(new_item)

with open('images.json', 'w', encoding='utf-8') as f:
    json.dump(filtered_data, f, ensure_ascii=False, indent=2)

# %%
# Lấy tất cả các product_category duy nhất
categories = list(set(item['product_category'] for item in filtered_data))

# Tạo mapping từ category sang số
category_to_int = {cat: idx for idx, cat in enumerate(categories)}

# Thêm trường product_category_int vào từng item
for item in filtered_data:
    item['product_category'] = category_to_int[item['product_category']]

# Xem mapping và ví dụ kết quả
print(category_to_int)
print(filtered_data[0]['product_category'], '->', filtered_data[0]['product_category'])
# Lưu thay đổi trực tiếp vào images.json
with open('images.json', 'w', encoding='utf-8') as f_json:
    json.dump(filtered_data, f_json, ensure_ascii=False, indent=2)
with open('category_mapping.md', 'w', encoding='utf-8') as f:
    for cat, idx in category_to_int.items():
        f.write(f"- {cat}: {idx}\n")
print("Đã lưu mapping category vào category_mapping.md")
# Out:
# {'book': 0, 'health&beauty': 1, 'sport': 2, 'food&drink': 3, 'stationery': 4}
# 3 -> 3
# Đã lưu mapping category vào category_mapping.md

# %%
import os
import requests
import json

def is_valid_url(url):
    # Kiểm tra url hợp lệ: bắt đầu bằng http hoặc https và có định dạng ảnh hợp lệ
    if not isinstance(url, str):
        return False
    if not url.startswith('http'):
        return False
    ext = os.path.splitext(url)[-1].split('?')[0].lower()
    if ext not in ['.jpg', '.jpeg', '.png', '.webp']:
        return False
    return True

# Đảm bảo thư mục lưu ảnh tồn tại
os.makedirs('downloaded_images', exist_ok=True)

# Đọc dữ liệu từ images.json
with open('images.json', 'r', encoding='utf-8') as f:
    samples = json.load(f)

image_mapping = {}

for sample in samples:
    id_ = sample['id']
    for idx, img_url in enumerate(sample['images']):
        if not is_valid_url(img_url):
            continue
        ext = os.path.splitext(img_url)[-1].split('?')[0]
        if ext.lower() not in ['.jpg', '.jpeg', '.png', '.webp']:
            ext = '.jpg'
        filename = f"{id_}_{idx}{ext}"
        filepath = os.path.join('downloaded_images', filename)
        try:
            response = requests.get(img_url, timeout=10)
            if response.status_code == 200:
                with open(filepath, 'wb') as img_file:
                    img_file.write(response.content)
                if id_ not in image_mapping:
                    image_mapping[id_] = []
                image_mapping[id_].append({'image_file': filename, 'url': img_url})
        except Exception as e:
            print(f"Không tải được ảnh {img_url}: {e}")

# Xuất file mapping dạng gộp theo id
with open('image_mapping.json', 'w', encoding='utf-8') as f:
    json.dump(image_mapping, f, ensure_ascii=False, indent=2)

print("Đã tải xong ảnh và xuất file mapping image_mapping.json")
# Out:
# Đã tải xong ảnh và xuất file mapping image_mapping.json

# %%
import os
import json
import random
from PIL import Image, ImageFilter
import numpy as np
import torchvision.transforms as transforms
import torch

# Đọc file image_mapping.json
with open('image_mapping.json', 'r') as f:
    image_mapping = json.load(f)

# Đường dẫn đến thư mục ảnh gốc và thư mục lưu ảnh đã xử lý
input_folder = 'downloaded_images'
output_folder = 'processed_images'

# Tạo thư mục processed_images nếu chưa tồn tại
os.makedirs(output_folder, exist_ok=True)

# Hàm resize với padding để giữ tỷ lệ khung hình
def resize_with_padding(image, target_size=(224, 224)):
    img_width, img_height = image.size
    target_width, target_height = target_size
    
    # Tính tỷ lệ để resize
    ratio = min(target_width / img_width, target_height / img_height)
    new_width = int(img_width * ratio)
    new_height = int(img_height * ratio)
    
    # Resize ảnh giữ tỷ lệ
    image = image.resize((new_width, new_height), Image.Resampling.LANCZOS)
    
    # Tạo ảnh nền đen với kích thước mục tiêu
    padded_image = Image.new('RGB', target_size, (0, 0, 0))  # Màu đen
    offset = ((target_width - new_width) // 2, (target_height - new_height) // 2)
    
    # Dán ảnh đã resize vào giữa ảnh nền
    padded_image.paste(image, offset)
    
    return padded_image

# Định nghĩa transform cơ bản (cho ảnh gốc)
base_transform = transforms.Compose([
    transforms.Lambda(lambda x: resize_with_padding(x)),  # Resize với padding
    transforms.Lambda(lambda x: x.filter(ImageFilter.GaussianBlur(radius=1))),  # Giảm nhiễu
    transforms.ToTensor(),  # Chuyển thành tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Chuẩn hóa
    transforms.ToPILImage()  # Chuyển lại thành PIL Image để lưu
])

# Định nghĩa các transform cho data augmentation
augment_transforms = {
    'flipped': transforms.Compose([
        transforms.Lambda(lambda x: resize_with_padding(x)),
        transforms.Lambda(lambda x: x.filter(ImageFilter.GaussianBlur(radius=1))),
        transforms.RandomHorizontalFlip(p=1.0),  # Lật ngang
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        transforms.ToPILImage()
    ]),
    'rotated': transforms.Compose([
        transforms.Lambda(lambda x: resize_with_padding(x)),
        transforms.Lambda(lambda x: x.filter(ImageFilter.GaussianBlur(radius=1))),
        transforms.RandomRotation(degrees=(-15, 15)),  # Xoay ngẫu nhiên [-15, 15] độ
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        transforms.ToPILImage()
    ]),
    'color': transforms.Compose([
        transforms.Lambda(lambda x: resize_with_padding(x)),
        transforms.Lambda(lambda x: x.filter(ImageFilter.GaussianBlur(radius=1))),
        transforms.ColorJitter(brightness=0.3, contrast=0.3),  # Điều chỉnh độ sáng/tương phản
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        transforms.ToPILImage()
    ])
}

# Tạo file ánh xạ mới
new_mapping = {}

# Xử lý từng ảnh
for item_id, images in image_mapping.items():
    new_mapping[item_id] = []
    for img_info in images:
        img_file = img_info['image_file']
        img_path = os.path.join(input_folder, img_file)
        
        # Kiểm tra file ảnh tồn tại
        if os.path.exists(img_path):
            try:
                # Load ảnh
                img = Image.open(img_path).convert('RGB')
                
                # Xử lý ảnh gốc
                processed_img = base_transform(img)
                output_path = os.path.join(output_folder, img_file)
                processed_img.save(output_path, format='JPEG', quality=95)
                print(f'Processed and saved original: {img_file}')
                
                # Lưu thông tin ảnh gốc vào file ánh xạ mới
                new_mapping[item_id].append({
                    'image_file': img_file,
                    'url': img_info.get('url', ''),
                    'type': 'original'
                })
                
                # Xử lý các phiên bản augment
                for aug_type, aug_transform in augment_transforms.items():
                    aug_img = aug_transform(img)
                    aug_file = f"{os.path.splitext(img_file)[0]}_{aug_type}{os.path.splitext(img_file)[1]}"
                    aug_output_path = os.path.join(output_folder, aug_file)
                    aug_img.save(aug_output_path, format='JPEG', quality=95)
                    print(f'Processed and saved augmented ({aug_type}): {aug_file}')
                    
                    # Lưu thông tin ảnh augment vào file ánh xạ mới
                    new_mapping[item_id].append({
                        'image_file': aug_file,
                        'url': img_info.get('url', ''),
                        'type': aug_type
                    })
                
            except Exception as e:
                print(f'Error processing {img_file}: {str(e)}')
        else:
            print(f'Image not found: {img_file}')

# Lưu file ánh xạ mới
with open('processed_image_mapping.json', 'w') as f:
    json.dump(new_mapping, f, indent=4)
print('Saved new mapping to processed_image_mapping.json')

print('Image preprocessing and augmentation completed.')
# Out:
# Processed and saved original: 211_0.jpg
# Processed and saved augmented (flipped): 211_0_flipped.jpg
# Processed and saved augmented (rotated): 211_0_rotated.jpg
# Processed and saved augmented (color): 211_0_color.jpg
# Processed and saved original: 215_0.jpg
# Processed and saved augmented (flipped): 215_0_flipped.jpg
# Processed and saved augmented (rotated): 215_0_rotated.jpg
# Processed and saved augmented (color): 215_0_color.jpg
# Processed and saved original: 215_1.jpg
# Processed and saved augmented (flipped): 215_1_flipped.jpg
# Processed and saved augmented (rotated): 215_1_rotated.jpg
# Processed and saved augmented (color): 215_1_color.jpg
# Processed and saved original: 215_2.jpg
# Processed and saved augmented (flipped): 215_2_flipped.jpg
# Processed and saved augmented (rotated): 215_2_rotated.jpg
# Processed and saved augmented (color): 215_2_color.jpg
# Processed and saved original: 215_1.jpg
# Processed and saved augmented (flipped): 215_1_flipped.jpg
# Processed and saved augmented (rotated): 215_1_rotated.jpg
# Processed and saved augmented (color): 215_1_color.jpg
# Processed and saved original: 215_2.jpg
# Processed and saved augmented (flipped): 215_2_flipped.jpg
# Processed and saved augmented (rotated): 215_2_rotated.jpg
# Processed and saved augmented (color): 215_2_color.jpg
# Processed and saved original: 217_0.jpg
# Processed and saved augmented (flipped): 217_0_flipped.jpg
# Processed and saved augmented (rotated): 217_0_rotated.jpg
# Processed and saved augmented (color): 217_0_color.jpg
# Processed and saved original: 217_1.jpg
# Processed and saved augmented (flipped): 217_1_flipped.jpg
# Processed and saved augmented (rotated): 217_1_rotated.jpg
# Processed and saved augmented (color): 217_1_color.jpg
# Processed and saved original: 218_0.jpg
# Processed and saved augmented (flipped): 218_0_flipped.jpg
# Processed and saved augmented (rotated): 218_0_rotated.jpg
# Processed and saved augmented (color): 218_0_color.jpg
# Processed and saved original: 224_0.jpg
# Processed and saved original: 217_0.jpg
# Processed and saved augmented (flipped): 217_0_flipped.jpg
# Processed and saved augmented (rotated): 217_0_rotated.jpg
# Processed and saved augmented (color): 217_0_color.jpg
# Processed and saved original: 217_1.jpg
# Processed and saved augmented (flipped): 217_1_flipped.jpg
# Processed and saved augmented (rotated): 217_1_rotated.jpg
# Processed and saved augmented (color): 217_1_color.jpg
# Processed and saved original: 218_0.jpg
# Processed and saved augmented (flipped): 218_0_flipped.jpg
# Processed and saved augmented (rotated): 218_0_rotated.jpg
# Processed and saved augmented (color): 218_0_color.jpg
# Processed and saved original: 224_0.jpg
# Processed and saved augmented (flipped): 224_0_flipped.jpg
# Processed and saved augmented (rotated): 224_0_rotated.jpg
# Processed and saved augmented (color): 224_0_color.jpg
# Processed and saved original: 228_0.jpg
# Processed and saved augmented (flipped): 228_0_flipped.jpg
# Processed and saved augmented (rotated): 228_0_rotated.jpg
# Processed and saved augmented (color): 228_0_color.jpg
# Processed and saved original: 228_1.jpg
# Processed and saved augmented (flipped): 224_0_flipped.jpg
# Processed and saved augmented (rotated): 224_0_rotated.jpg
# Processed and saved augmented (color): 224_0_color.jpg
# Processed and saved original: 228_0.jpg
# Processed and saved augmented (flipped): 228_0_flipped.jpg
# Processed and saved augmented (rotated): 228_0_rotated.jpg
# Processed and saved augmented (color): 228_0_color.jpg
# Processed and saved original: 228_1.jpg
# Processed and saved augmented (flipped): 228_1_flipped.jpg
# Processed and saved augmented (rotated): 228_1_rotated.jpg
# Processed and saved augmented (color): 228_1_color.jpg
# Processed and saved original: 228_2.jpg
# Processed and saved augmented (flipped): 228_2_flipped.jpg
# Processed and saved augmented (rotated): 228_2_rotated.jpg
# Processed and saved augmented (color): 228_2_color.jpg
# Processed and saved original: 232_0.jpg
# Processed and saved augmented (flipped): 232_0_flipped.jpg
# Processed and saved augmented (rotated): 232_0_rotated.jpg
# Processed and saved augmented (color): 232_0_color.jpg
# Processed and saved augmented (flipped): 228_1_flipped.jpg
# Processed and saved augmented (rotated): 228_1_rotated.jpg
# Processed and saved augmented (color): 228_1_color.jpg
# Processed and saved original: 228_2.jpg
# Processed and saved augmented (flipped): 228_2_flipped.jpg
# Processed and saved augmented (rotated): 228_2_rotated.jpg
# Processed and saved augmented (color): 228_2_color.jpg
# Processed and saved original: 232_0.jpg
# Processed and saved augmented (flipped): 232_0_flipped.jpg
# Processed and saved augmented (rotated): 232_0_rotated.jpg
# Processed and saved augmented (color): 232_0_color.jpg
# Processed and saved original: 234_0.jpg
# Processed and saved augmented (flipped): 234_0_flipped.jpg
# Processed and saved augmented (rotated): 234_0_rotated.jpg
# Processed and saved augmented (color): 234_0_color.jpg
# Processed and saved original: 237_0.jpg
# Processed and saved augmented (flipped): 237_0_flipped.jpg
# Processed and saved augmented (rotated): 237_0_rotated.jpg
# Processed and saved augmented (color): 237_0_color.jpg
# Processed and saved original: 239_0.jpg
# Processed and saved augmented (flipped): 239_0_flipped.jpg
# Processed and saved augmented (rotated): 239_0_rotated.jpg
# Processed and saved augmented (color): 239_0_color.jpg
# Processed and saved original: 239_1.jpg
# Processed and saved augmented (flipped): 239_1_flipped.jpg
# Processed and saved original: 234_0.jpg
# Processed and saved augmented (flipped): 234_0_flipped.jpg
# Processed and saved augmented (rotated): 234_0_rotated.jpg
# Processed and saved augmented (color): 234_0_color.jpg
# Processed and saved original: 237_0.jpg
# Processed and saved augmented (flipped): 237_0_flipped.jpg
# Processed and saved augmented (rotated): 237_0_rotated.jpg
# Processed and saved augmented (color): 237_0_color.jpg
# Processed and saved original: 239_0.jpg
# Processed and saved augmented (flipped): 239_0_flipped.jpg
# Processed and saved augmented (rotated): 239_0_rotated.jpg
# Processed and saved augmented (color): 239_0_color.jpg
# Processed and saved original: 239_1.jpg
# Processed and saved augmented (flipped): 239_1_flipped.jpg
# Processed and saved augmented (rotated): 239_1_rotated.jpg
# Processed and saved augmented (color): 239_1_color.jpg
# Processed and saved original: 241_0.jpg
# Processed and saved augmented (flipped): 241_0_flipped.jpg
# Processed and saved augmented (rotated): 241_0_rotated.jpg
# Processed and saved augmented (color): 241_0_color.jpg
# Processed and saved original: 242_0.jpg
# Processed and saved augmented (flipped): 242_0_flipped.jpg
# Processed and saved augmented (rotated): 242_0_rotated.jpg
# Processed and saved augmented (color): 242_0_color.jpg
# Processed and saved original: 242_1.jpg
# Processed and saved augmented (flipped): 242_1_flipped.jpg
# Processed and saved augmented (rotated): 242_1_rotated.jpg
# Processed and saved augmented (color): 242_1_color.jpg
# Processed and saved original: 243_0.jpg
# Processed and saved augmented (flipped): 243_0_flipped.jpg
# Processed and saved augmented (rotated): 243_0_rotated.jpg
# Processed and saved augmented (rotated): 239_1_rotated.jpg
# Processed and saved augmented (color): 239_1_color.jpg
# Processed and saved original: 241_0.jpg
# Processed and saved augmented (flipped): 241_0_flipped.jpg
# Processed and saved augmented (rotated): 241_0_rotated.jpg
# Processed and saved augmented (color): 241_0_color.jpg
# Processed and saved original: 242_0.jpg
# Processed and saved augmented (flipped): 242_0_flipped.jpg
# Processed and saved augmented (rotated): 242_0_rotated.jpg
# Processed and saved augmented (color): 242_0_color.jpg
# Processed and saved original: 242_1.jpg
# Processed and saved augmented (flipped): 242_1_flipped.jpg
# Processed and saved augmented (rotated): 242_1_rotated.jpg
# Processed and saved augmented (color): 242_1_color.jpg
# Processed and saved original: 243_0.jpg
# Processed and saved augmented (flipped): 243_0_flipped.jpg
# Processed and saved augmented (rotated): 243_0_rotated.jpg
# Processed and saved augmented (color): 243_0_color.jpg
# Processed and saved original: 244_0.jpg
# Processed and saved augmented (flipped): 244_0_flipped.jpg
# Processed and saved augmented (rotated): 244_0_rotated.jpg
# Processed and saved augmented (color): 244_0_color.jpg
# Processed and saved original: 245_0.jpg
# Processed and saved augmented (flipped): 245_0_flipped.jpg
# Processed and saved augmented (rotated): 245_0_rotated.jpg
# Processed and saved augmented (color): 245_0_color.jpg
# Processed and saved original: 248_0.jpg
# Processed and saved augmented (flipped): 248_0_flipped.jpg
# Processed and saved augmented (rotated): 248_0_rotated.jpg
# Processed and saved augmented (color): 248_0_color.jpg
# Processed and saved original: 249_0.jpg
# Processed and saved augmented (flipped): 249_0_flipped.jpg
# Processed and saved augmented (color): 243_0_color.jpg
# Processed and saved original: 244_0.jpg
# Processed and saved augmented (flipped): 244_0_flipped.jpg
# Processed and saved augmented (rotated): 244_0_rotated.jpg
# Processed and saved augmented (color): 244_0_color.jpg
# Processed and saved original: 245_0.jpg
# Processed and saved augmented (flipped): 245_0_flipped.jpg
# Processed and saved augmented (rotated): 245_0_rotated.jpg
# Processed and saved augmented (color): 245_0_color.jpg
# Processed and saved original: 248_0.jpg
# Processed and saved augmented (flipped): 248_0_flipped.jpg
# Processed and saved augmented (rotated): 248_0_rotated.jpg
# Processed and saved augmented (color): 248_0_color.jpg
# Processed and saved original: 249_0.jpg
# Processed and saved augmented (flipped): 249_0_flipped.jpg
# Processed and saved augmented (rotated): 249_0_rotated.jpg
# Processed and saved augmented (color): 249_0_color.jpg
# Processed and saved original: 253_0.jpg
# Processed and saved augmented (flipped): 253_0_flipped.jpg
# Processed and saved augmented (rotated): 253_0_rotated.jpg
# Processed and saved augmented (color): 253_0_color.jpg
# Processed and saved original: 257_0.jpg
# Processed and saved augmented (flipped): 257_0_flipped.jpg
# Processed and saved augmented (rotated): 257_0_rotated.jpg
# Processed and saved augmented (color): 257_0_color.jpg
# Processed and saved original: 257_1.jpg
# Processed and saved augmented (flipped): 257_1_flipped.jpg
# Processed and saved augmented (rotated): 257_1_rotated.jpg
# Processed and saved augmented (color): 257_1_color.jpg
# Processed and saved original: 257_2.jpg
# Processed and saved augmented (flipped): 257_2_flipped.jpg
# Processed and saved augmented (rotated): 249_0_rotated.jpg
# Processed and saved augmented (color): 249_0_color.jpg
# Processed and saved original: 253_0.jpg
# Processed and saved augmented (flipped): 253_0_flipped.jpg
# Processed and saved augmented (rotated): 253_0_rotated.jpg
# Processed and saved augmented (color): 253_0_color.jpg
# Processed and saved original: 257_0.jpg
# Processed and saved augmented (flipped): 257_0_flipped.jpg
# Processed and saved augmented (rotated): 257_0_rotated.jpg
# Processed and saved augmented (color): 257_0_color.jpg
# Processed and saved original: 257_1.jpg
# Processed and saved augmented (flipped): 257_1_flipped.jpg
# Processed and saved augmented (rotated): 257_1_rotated.jpg
# Processed and saved augmented (color): 257_1_color.jpg
# Processed and saved original: 257_2.jpg
# Processed and saved augmented (flipped): 257_2_flipped.jpg
# Processed and saved augmented (rotated): 257_2_rotated.jpg
# Processed and saved augmented (color): 257_2_color.jpg
# Processed and saved original: 257_3.jpg
# Processed and saved augmented (flipped): 257_3_flipped.jpg
# Processed and saved augmented (rotated): 257_3_rotated.jpg
# Processed and saved augmented (color): 257_3_color.jpg
# Processed and saved original: 257_4.jpg
# Processed and saved augmented (flipped): 257_4_flipped.jpg
# Processed and saved augmented (rotated): 257_4_rotated.jpg
# Processed and saved augmented (color): 257_4_color.jpg
# Processed and saved original: 262_0.jpg
# Processed and saved augmented (rotated): 257_2_rotated.jpg
# Processed and saved augmented (color): 257_2_color.jpg
# Processed and saved original: 257_3.jpg
# Processed and saved augmented (flipped): 257_3_flipped.jpg
# Processed and saved augmented (rotated): 257_3_rotated.jpg
# Processed and saved augmented (color): 257_3_color.jpg
# Processed and saved original: 257_4.jpg
# Processed and saved augmented (flipped): 257_4_flipped.jpg
# Processed and saved augmented (rotated): 257_4_rotated.jpg
# Processed and saved augmented (color): 257_4_color.jpg
# Processed and saved original: 262_0.jpg
# Processed and saved augmented (flipped): 262_0_flipped.jpg
# Processed and saved augmented (rotated): 262_0_rotated.jpg
# Processed and saved augmented (color): 262_0_color.jpg
# Processed and saved original: 263_0.jpg
# Processed and saved augmented (flipped): 263_0_flipped.jpg
# Processed and saved augmented (rotated): 263_0_rotated.jpg
# Processed and saved augmented (color): 263_0_color.jpg
# Processed and saved original: 268_0.jpg
# Processed and saved augmented (flipped): 268_0_flipped.jpg
# Processed and saved augmented (rotated): 268_0_rotated.jpg
# Processed and saved augmented (color): 268_0_color.jpg
# Processed and saved original: 268_1.jpg
# Processed and saved augmented (flipped): 268_1_flipped.jpg
# Processed and saved augmented (rotated): 268_1_rotated.jpg
# Processed and saved augmented (color): 268_1_color.jpg
# Processed and saved original: 269_0.jpg
# Processed and saved augmented (flipped): 269_0_flipped.jpg
# Processed and saved augmented (rotated): 269_0_rotated.jpg
# Processed and saved augmented (flipped): 262_0_flipped.jpg
# Processed and saved augmented (rotated): 262_0_rotated.jpg
# Processed and saved augmented (color): 262_0_color.jpg
# Processed and saved original: 263_0.jpg
# Processed and saved augmented (flipped): 263_0_flipped.jpg
# Processed and saved augmented (rotated): 263_0_rotated.jpg
# Processed and saved augmented (color): 263_0_color.jpg
# Processed and saved original: 268_0.jpg
# Processed and saved augmented (flipped): 268_0_flipped.jpg
# Processed and saved augmented (rotated): 268_0_rotated.jpg
# Processed and saved augmented (color): 268_0_color.jpg
# Processed and saved original: 268_1.jpg
# Processed and saved augmented (flipped): 268_1_flipped.jpg
# Processed and saved augmented (rotated): 268_1_rotated.jpg
# Processed and saved augmented (color): 268_1_color.jpg
# Processed and saved original: 269_0.jpg
# Processed and saved augmented (flipped): 269_0_flipped.jpg
# Processed and saved augmented (rotated): 269_0_rotated.jpg
# Processed and saved augmented (color): 269_0_color.jpg
# Processed and saved original: 269_1.jpg
# Processed and saved augmented (flipped): 269_1_flipped.jpg
# Processed and saved augmented (rotated): 269_1_rotated.jpg
# Processed and saved augmented (color): 269_1_color.jpg
# Processed and saved original: 277_0.jpg
# Processed and saved augmented (flipped): 277_0_flipped.jpg
# Processed and saved augmented (rotated): 277_0_rotated.jpg
# Processed and saved augmented (color): 277_0_color.jpg
# Processed and saved original: 277_1.jpg
# Processed and saved augmented (flipped): 277_1_flipped.jpg
# Processed and saved augmented (color): 269_0_color.jpg
# Processed and saved original: 269_1.jpg
# Processed and saved augmented (flipped): 269_1_flipped.jpg
# Processed and saved augmented (rotated): 269_1_rotated.jpg
# Processed and saved augmented (color): 269_1_color.jpg
# Processed and saved original: 277_0.jpg
# Processed and saved augmented (flipped): 277_0_flipped.jpg
# Processed and saved augmented (rotated): 277_0_rotated.jpg
# Processed and saved augmented (color): 277_0_color.jpg
# Processed and saved original: 277_1.jpg
# Processed and saved augmented (flipped): 277_1_flipped.jpg
# Processed and saved augmented (rotated): 277_1_rotated.jpg
# Processed and saved augmented (color): 277_1_color.jpg
# Processed and saved original: 277_2.jpg
# Processed and saved augmented (flipped): 277_2_flipped.jpg
# Processed and saved augmented (rotated): 277_2_rotated.jpg
# Processed and saved augmented (color): 277_2_color.jpg
# Processed and saved original: 277_3.jpg
# Processed and saved augmented (flipped): 277_3_flipped.jpg
# Processed and saved augmented (rotated): 277_3_rotated.jpg
# Processed and saved augmented (rotated): 277_1_rotated.jpg
# Processed and saved augmented (color): 277_1_color.jpg
# Processed and saved original: 277_2.jpg
# Processed and saved augmented (flipped): 277_2_flipped.jpg
# Processed and saved augmented (rotated): 277_2_rotated.jpg
# Processed and saved augmented (color): 277_2_color.jpg
# Processed and saved original: 277_3.jpg
# Processed and saved augmented (flipped): 277_3_flipped.jpg
# Processed and saved augmented (rotated): 277_3_rotated.jpg
# Processed and saved augmented (color): 277_3_color.jpg
# Processed and saved original: 278_0.jpg
# Processed and saved augmented (flipped): 278_0_flipped.jpg
# Processed and saved augmented (rotated): 278_0_rotated.jpg
# Processed and saved augmented (color): 278_0_color.jpg
# Processed and saved original: 280_0.jpg
# Processed and saved augmented (flipped): 280_0_flipped.jpg
# Processed and saved augmented (rotated): 280_0_rotated.jpg
# Processed and saved augmented (color): 280_0_color.jpg
# Processed and saved original: 282_0.jpg
# Processed and saved augmented (flipped): 282_0_flipped.jpg
# Processed and saved augmented (rotated): 282_0_rotated.jpg
# Processed and saved augmented (color): 282_0_color.jpg
# Processed and saved original: 283_0.jpg
# Processed and saved augmented (flipped): 283_0_flipped.jpg
# Processed and saved augmented (rotated): 283_0_rotated.jpg
# Processed and saved augmented (color): 283_0_color.jpg
# Processed and saved original: 284_0.jpg
# Processed and saved augmented (flipped): 284_0_flipped.jpg
# Processed and saved augmented (rotated): 284_0_rotated.jpg
# Processed and saved augmented (color): 284_0_color.jpg
# Processed and saved original: 286_0.jpg
# Processed and saved augmented (color): 277_3_color.jpg
# Processed and saved original: 278_0.jpg
# Processed and saved augmented (flipped): 278_0_flipped.jpg
# Processed and saved augmented (rotated): 278_0_rotated.jpg
# Processed and saved augmented (color): 278_0_color.jpg
# Processed and saved original: 280_0.jpg
# Processed and saved augmented (flipped): 280_0_flipped.jpg
# Processed and saved augmented (rotated): 280_0_rotated.jpg
# Processed and saved augmented (color): 280_0_color.jpg
# Processed and saved original: 282_0.jpg
# Processed and saved augmented (flipped): 282_0_flipped.jpg
# Processed and saved augmented (rotated): 282_0_rotated.jpg
# Processed and saved augmented (color): 282_0_color.jpg
# Processed and saved original: 283_0.jpg
# Processed and saved augmented (flipped): 283_0_flipped.jpg
# Processed and saved augmented (rotated): 283_0_rotated.jpg
# Processed and saved augmented (color): 283_0_color.jpg
# Processed and saved original: 284_0.jpg
# Processed and saved augmented (flipped): 284_0_flipped.jpg
# Processed and saved augmented (rotated): 284_0_rotated.jpg
# Processed and saved augmented (color): 284_0_color.jpg
# Processed and saved original: 286_0.jpg
# Processed and saved augmented (flipped): 286_0_flipped.jpg
# Processed and saved augmented (rotated): 286_0_rotated.jpg
# Processed and saved augmented (color): 286_0_color.jpg
# Processed and saved original: 286_1.jpg
# Processed and saved augmented (flipped): 286_1_flipped.jpg
# Processed and saved augmented (rotated): 286_1_rotated.jpg
# Processed and saved augmented (color): 286_1_color.jpg
# Processed and saved original: 288_0.jpg
# Processed and saved augmented (flipped): 288_0_flipped.jpg
# Processed and saved augmented (rotated): 288_0_rotated.jpg
# Processed and saved augmented (color): 288_0_color.jpg
# Processed and saved original: 292_0.jpg
# Processed and saved augmented (flipped): 292_0_flipped.jpg
# Processed and saved augmented (rotated): 292_0_rotated.jpg
# Processed and saved augmented (color): 292_0_color.jpg
# Processed and saved original: 292_1.jpg
# Processed and saved augmented (flipped): 292_1_flipped.jpg
# Processed and saved augmented (rotated): 292_1_rotated.jpg
# Processed and saved augmented (color): 292_1_color.jpg
# Processed and saved original: 293_0.jpg
# Processed and saved augmented (flipped): 293_0_flipped.jpg
# Processed and saved augmented (rotated): 293_0_rotated.jpg
# Processed and saved augmented (flipped): 286_0_flipped.jpg
# Processed and saved augmented (rotated): 286_0_rotated.jpg
# Processed and saved augmented (color): 286_0_color.jpg
# Processed and saved original: 286_1.jpg
# Processed and saved augmented (flipped): 286_1_flipped.jpg
# Processed and saved augmented (rotated): 286_1_rotated.jpg
# Processed and saved augmented (color): 286_1_color.jpg
# Processed and saved original: 288_0.jpg
# Processed and saved augmented (flipped): 288_0_flipped.jpg
# Processed and saved augmented (rotated): 288_0_rotated.jpg
# Processed and saved augmented (color): 288_0_color.jpg
# Processed and saved original: 292_0.jpg
# Processed and saved augmented (flipped): 292_0_flipped.jpg
# Processed and saved augmented (rotated): 292_0_rotated.jpg
# Processed and saved augmented (color): 292_0_color.jpg
# Processed and saved original: 292_1.jpg
# Processed and saved augmented (flipped): 292_1_flipped.jpg
# Processed and saved augmented (rotated): 292_1_rotated.jpg
# Processed and saved augmented (color): 292_1_color.jpg
# Processed and saved original: 293_0.jpg
# Processed and saved augmented (flipped): 293_0_flipped.jpg
# Processed and saved augmented (rotated): 293_0_rotated.jpg
# Processed and saved augmented (color): 293_0_color.jpg
# Processed and saved original: 293_1.jpg
# Processed and saved augmented (flipped): 293_1_flipped.jpg
# Processed and saved augmented (rotated): 293_1_rotated.jpg
# Processed and saved augmented (color): 293_1_color.jpg
# Processed and saved original: 297_0.jpg
# Processed and saved augmented (flipped): 297_0_flipped.jpg
# Processed and saved augmented (rotated): 297_0_rotated.jpg
# Processed and saved augmented (color): 297_0_color.jpg
# Processed and saved original: 297_1.jpg
# Processed and saved augmented (flipped): 297_1_flipped.jpg
# Processed and saved augmented (rotated): 297_1_rotated.jpg
# Processed and saved augmented (color): 293_0_color.jpg
# Processed and saved original: 293_1.jpg
# Processed and saved augmented (flipped): 293_1_flipped.jpg
# Processed and saved augmented (rotated): 293_1_rotated.jpg
# Processed and saved augmented (color): 293_1_color.jpg
# Processed and saved original: 297_0.jpg
# Processed and saved augmented (flipped): 297_0_flipped.jpg
# Processed and saved augmented (rotated): 297_0_rotated.jpg
# Processed and saved augmented (color): 297_0_color.jpg
# Processed and saved original: 297_1.jpg
# Processed and saved augmented (flipped): 297_1_flipped.jpg
# Processed and saved augmented (rotated): 297_1_rotated.jpg
# Processed and saved augmented (color): 297_1_color.jpg
# Processed and saved original: 297_2.jpg
# Processed and saved augmented (flipped): 297_2_flipped.jpg
# Processed and saved augmented (rotated): 297_2_rotated.jpg
# Processed and saved augmented (color): 297_2_color.jpg
# Processed and saved original: 297_3.jpg
# Processed and saved augmented (flipped): 297_3_flipped.jpg
# Processed and saved augmented (rotated): 297_3_rotated.jpg
# Processed and saved augmented (color): 297_3_color.jpg
# Processed and saved original: 298_0.jpg
# Processed and saved augmented (color): 297_1_color.jpg
# Processed and saved original: 297_2.jpg
# Processed and saved augmented (flipped): 297_2_flipped.jpg
# Processed and saved augmented (rotated): 297_2_rotated.jpg
# Processed and saved augmented (color): 297_2_color.jpg
# Processed and saved original: 297_3.jpg
# Processed and saved augmented (flipped): 297_3_flipped.jpg
# Processed and saved augmented (rotated): 297_3_rotated.jpg
# Processed and saved augmented (color): 297_3_color.jpg
# Processed and saved original: 298_0.jpg
# Processed and saved augmented (flipped): 298_0_flipped.jpg
# Processed and saved augmented (rotated): 298_0_rotated.jpg
# Processed and saved augmented (color): 298_0_color.jpg
# Processed and saved original: 298_1.jpg
# Processed and saved augmented (flipped): 298_1_flipped.jpg
# Processed and saved augmented (rotated): 298_1_rotated.jpg
# Processed and saved augmented (color): 298_1_color.jpg
# Processed and saved original: 298_2.jpg
# Processed and saved augmented (flipped): 298_2_flipped.jpg
# Processed and saved augmented (rotated): 298_2_rotated.jpg
# Processed and saved augmented (color): 298_2_color.jpg
# Processed and saved augmented (flipped): 298_0_flipped.jpg
# Processed and saved augmented (rotated): 298_0_rotated.jpg
# Processed and saved augmented (color): 298_0_color.jpg
# Processed and saved original: 298_1.jpg
# Processed and saved augmented (flipped): 298_1_flipped.jpg
# Processed and saved augmented (rotated): 298_1_rotated.jpg
# Processed and saved augmented (color): 298_1_color.jpg
# Processed and saved original: 298_2.jpg
# Processed and saved augmented (flipped): 298_2_flipped.jpg
# Processed and saved augmented (rotated): 298_2_rotated.jpg
# Processed and saved augmented (color): 298_2_color.jpg
# Processed and saved original: 300_0.jpg
# Processed and saved augmented (flipped): 300_0_flipped.jpg
# Processed and saved augmented (rotated): 300_0_rotated.jpg
# Processed and saved augmented (color): 300_0_color.jpg
# Processed and saved original: 302_0.jpg
# Processed and saved augmented (flipped): 302_0_flipped.jpg
# Processed and saved augmented (rotated): 302_0_rotated.jpg
# Processed and saved augmented (color): 302_0_color.jpg
# Processed and saved original: 302_1.jpg
# Processed and saved augmented (flipped): 302_1_flipped.jpg
# Processed and saved augmented (rotated): 302_1_rotated.jpg
# Processed and saved augmented (color): 302_1_color.jpg
# Processed and saved original: 302_2.jpg
# Processed and saved augmented (flipped): 302_2_flipped.jpg
# Processed and saved augmented (rotated): 302_2_rotated.jpg
# Processed and saved augmented (color): 302_2_color.jpg
# Processed and saved original: 306_0.jpg
# Processed and saved augmented (flipped): 306_0_flipped.jpg
# Processed and saved augmented (rotated): 306_0_rotated.jpg
# Processed and saved augmented (color): 306_0_color.jpg
# Processed and saved original: 300_0.jpg
# Processed and saved augmented (flipped): 300_0_flipped.jpg
# Processed and saved augmented (rotated): 300_0_rotated.jpg
# Processed and saved augmented (color): 300_0_color.jpg
# Processed and saved original: 302_0.jpg
# Processed and saved augmented (flipped): 302_0_flipped.jpg
# Processed and saved augmented (rotated): 302_0_rotated.jpg
# Processed and saved augmented (color): 302_0_color.jpg
# Processed and saved original: 302_1.jpg
# Processed and saved augmented (flipped): 302_1_flipped.jpg
# Processed and saved augmented (rotated): 302_1_rotated.jpg
# Processed and saved augmented (color): 302_1_color.jpg
# Processed and saved original: 302_2.jpg
# Processed and saved augmented (flipped): 302_2_flipped.jpg
# Processed and saved augmented (rotated): 302_2_rotated.jpg
# Processed and saved augmented (color): 302_2_color.jpg
# Processed and saved original: 306_0.jpg
# Processed and saved augmented (flipped): 306_0_flipped.jpg
# Processed and saved augmented (rotated): 306_0_rotated.jpg
# Processed and saved augmented (color): 306_0_color.jpg
# Processed and saved original: 307_0.jpg
# Processed and saved augmented (flipped): 307_0_flipped.jpg
# Processed and saved augmented (rotated): 307_0_rotated.jpg
# Processed and saved augmented (color): 307_0_color.jpg
# Processed and saved original: 307_1.jpg
# Processed and saved augmented (flipped): 307_1_flipped.jpg
# Processed and saved augmented (rotated): 307_1_rotated.jpg
# Processed and saved augmented (color): 307_1_color.jpg
# Processed and saved original: 307_2.jpg
# Processed and saved augmented (flipped): 307_2_flipped.jpg
# Processed and saved augmented (rotated): 307_2_rotated.jpg
# Processed and saved augmented (color): 307_2_color.jpg
# Processed and saved original: 307_3.jpg
# Processed and saved augmented (flipped): 307_3_flipped.jpg
# Processed and saved augmented (rotated): 307_3_rotated.jpg
# Processed and saved augmented (color): 307_3_color.jpg
# Processed and saved original: 307_0.jpg
# Processed and saved augmented (flipped): 307_0_flipped.jpg
# Processed and saved augmented (rotated): 307_0_rotated.jpg
# Processed and saved augmented (color): 307_0_color.jpg
# Processed and saved original: 307_1.jpg
# Processed and saved augmented (flipped): 307_1_flipped.jpg
# Processed and saved augmented (rotated): 307_1_rotated.jpg
# Processed and saved augmented (color): 307_1_color.jpg
# Processed and saved original: 307_2.jpg
# Processed and saved augmented (flipped): 307_2_flipped.jpg
# Processed and saved augmented (rotated): 307_2_rotated.jpg
# Processed and saved augmented (color): 307_2_color.jpg
# Processed and saved original: 307_3.jpg
# Processed and saved augmented (flipped): 307_3_flipped.jpg
# Processed and saved augmented (rotated): 307_3_rotated.jpg
# Processed and saved augmented (color): 307_3_color.jpg
# Processed and saved original: 310_0.jpg
# Processed and saved augmented (flipped): 310_0_flipped.jpg
# Processed and saved augmented (rotated): 310_0_rotated.jpg
# Processed and saved augmented (color): 310_0_color.jpg
# Processed and saved original: 312_0.jpg
# Processed and saved augmented (flipped): 312_0_flipped.jpg
# Processed and saved augmented (rotated): 312_0_rotated.jpg
# Processed and saved augmented (color): 312_0_color.jpg
# Processed and saved original: 313_0.jpg
# Processed and saved augmented (flipped): 313_0_flipped.jpg
# Processed and saved augmented (rotated): 313_0_rotated.jpg
# Processed and saved augmented (color): 313_0_color.jpg
# Processed and saved original: 310_0.jpg
# Processed and saved augmented (flipped): 310_0_flipped.jpg
# Processed and saved augmented (rotated): 310_0_rotated.jpg
# Processed and saved augmented (color): 310_0_color.jpg
# Processed and saved original: 312_0.jpg
# Processed and saved augmented (flipped): 312_0_flipped.jpg
# Processed and saved augmented (rotated): 312_0_rotated.jpg
# Processed and saved augmented (color): 312_0_color.jpg
# Processed and saved original: 313_0.jpg
# Processed and saved augmented (flipped): 313_0_flipped.jpg
# Processed and saved augmented (rotated): 313_0_rotated.jpg
# Processed and saved augmented (color): 313_0_color.jpg
# Processed and saved original: 313_1.jpg
# Processed and saved augmented (flipped): 313_1_flipped.jpg
# Processed and saved augmented (rotated): 313_1_rotated.jpg
# Processed and saved augmented (color): 313_1_color.jpg
# Processed and saved original: 315_0.jpg
# Processed and saved augmented (flipped): 315_0_flipped.jpg
# Processed and saved augmented (rotated): 315_0_rotated.jpg
# Processed and saved augmented (color): 315_0_color.jpg
# Processed and saved original: 316_0.jpg
# Processed and saved augmented (flipped): 316_0_flipped.jpg
# Processed and saved augmented (rotated): 316_0_rotated.jpg
# Processed and saved augmented (color): 316_0_color.jpg
# Processed and saved original: 316_1.jpg
# Processed and saved augmented (flipped): 316_1_flipped.jpg
# Processed and saved augmented (rotated): 316_1_rotated.jpg
# Processed and saved augmented (color): 316_1_color.jpg
# Processed and saved original: 316_2.jpg
# Processed and saved original: 313_1.jpg
# Processed and saved augmented (flipped): 313_1_flipped.jpg
# Processed and saved augmented (rotated): 313_1_rotated.jpg
# Processed and saved augmented (color): 313_1_color.jpg
# Processed and saved original: 315_0.jpg
# Processed and saved augmented (flipped): 315_0_flipped.jpg
# Processed and saved augmented (rotated): 315_0_rotated.jpg
# Processed and saved augmented (color): 315_0_color.jpg
# Processed and saved original: 316_0.jpg
# Processed and saved augmented (flipped): 316_0_flipped.jpg
# Processed and saved augmented (rotated): 316_0_rotated.jpg
# Processed and saved augmented (color): 316_0_color.jpg
# Processed and saved original: 316_1.jpg
# Processed and saved augmented (flipped): 316_1_flipped.jpg
# Processed and saved augmented (rotated): 316_1_rotated.jpg
# Processed and saved augmented (color): 316_1_color.jpg
# Processed and saved original: 316_2.jpg
# Processed and saved augmented (flipped): 316_2_flipped.jpg
# Processed and saved augmented (rotated): 316_2_rotated.jpg
# Processed and saved augmented (color): 316_2_color.jpg
# Processed and saved original: 316_3.jpg
# Processed and saved augmented (flipped): 316_3_flipped.jpg
# Processed and saved augmented (rotated): 316_3_rotated.jpg
# Processed and saved augmented (color): 316_3_color.jpg
# Processed and saved original: 318_0.jpg
# Processed and saved augmented (flipped): 318_0_flipped.jpg
# Processed and saved augmented (rotated): 318_0_rotated.jpg
# Processed and saved augmented (color): 318_0_color.jpg
# Processed and saved original: 318_1.jpg
# Processed and saved augmented (flipped): 318_1_flipped.jpg
# Processed and saved augmented (rotated): 318_1_rotated.jpg
# Processed and saved augmented (color): 318_1_color.jpg
# Processed and saved original: 318_2.jpg
# Processed and saved augmented (flipped): 318_2_flipped.jpg
# Processed and saved augmented (rotated): 318_2_rotated.jpg
# Processed and saved augmented (flipped): 316_2_flipped.jpg
# Processed and saved augmented (rotated): 316_2_rotated.jpg
# Processed and saved augmented (color): 316_2_color.jpg
# Processed and saved original: 316_3.jpg
# Processed and saved augmented (flipped): 316_3_flipped.jpg
# Processed and saved augmented (rotated): 316_3_rotated.jpg
# Processed and saved augmented (color): 316_3_color.jpg
# Processed and saved original: 318_0.jpg
# Processed and saved augmented (flipped): 318_0_flipped.jpg
# Processed and saved augmented (rotated): 318_0_rotated.jpg
# Processed and saved augmented (color): 318_0_color.jpg
# Processed and saved original: 318_1.jpg
# Processed and saved augmented (flipped): 318_1_flipped.jpg
# Processed and saved augmented (rotated): 318_1_rotated.jpg
# Processed and saved augmented (color): 318_1_color.jpg
# Processed and saved original: 318_2.jpg
# Processed and saved augmented (flipped): 318_2_flipped.jpg
# Processed and saved augmented (rotated): 318_2_rotated.jpg
# Processed and saved augmented (color): 318_2_color.jpg
# Processed and saved original: 319_0.jpg
# Processed and saved augmented (flipped): 319_0_flipped.jpg
# Processed and saved augmented (rotated): 319_0_rotated.jpg
# Processed and saved augmented (color): 319_0_color.jpg
# Processed and saved original: 319_1.jpg
# Processed and saved augmented (flipped): 319_1_flipped.jpg
# Processed and saved augmented (rotated): 319_1_rotated.jpg
# Processed and saved augmented (color): 319_1_color.jpg
# Processed and saved original: 319_2.jpg
# Processed and saved augmented (flipped): 319_2_flipped.jpg
# Processed and saved augmented (rotated): 319_2_rotated.jpg
# Processed and saved augmented (color): 319_2_color.jpg
# Processed and saved original: 320_0.jpg
# Processed and saved augmented (flipped): 320_0_flipped.jpg
# Processed and saved augmented (rotated): 320_0_rotated.jpg
# Processed and saved augmented (color): 318_2_color.jpg
# Processed and saved original: 319_0.jpg
# Processed and saved augmented (flipped): 319_0_flipped.jpg
# Processed and saved augmented (rotated): 319_0_rotated.jpg
# Processed and saved augmented (color): 319_0_color.jpg
# Processed and saved original: 319_1.jpg
# Processed and saved augmented (flipped): 319_1_flipped.jpg
# Processed and saved augmented (rotated): 319_1_rotated.jpg
# Processed and saved augmented (color): 319_1_color.jpg
# Processed and saved original: 319_2.jpg
# Processed and saved augmented (flipped): 319_2_flipped.jpg
# Processed and saved augmented (rotated): 319_2_rotated.jpg
# Processed and saved augmented (color): 319_2_color.jpg
# Processed and saved original: 320_0.jpg
# Processed and saved augmented (flipped): 320_0_flipped.jpg
# Processed and saved augmented (rotated): 320_0_rotated.jpg
# Processed and saved augmented (color): 320_0_color.jpg
# Processed and saved original: 320_1.jpg
# Processed and saved augmented (flipped): 320_1_flipped.jpg
# Processed and saved augmented (rotated): 320_1_rotated.jpg
# Processed and saved augmented (color): 320_1_color.jpg
# Processed and saved original: 325_0.jpg
# Processed and saved augmented (flipped): 325_0_flipped.jpg
# Processed and saved augmented (rotated): 325_0_rotated.jpg
# Processed and saved augmented (color): 325_0_color.jpg
# Processed and saved original: 325_1.jpg
# Processed and saved augmented (flipped): 325_1_flipped.jpg
# Processed and saved augmented (rotated): 325_1_rotated.jpg
# Processed and saved augmented (color): 325_1_color.jpg
# Processed and saved original: 325_2.jpg
# Processed and saved augmented (flipped): 325_2_flipped.jpg
# Processed and saved augmented (rotated): 325_2_rotated.jpg
# Processed and saved augmented (color): 325_2_color.jpg
# Processed and saved original: 325_3.jpg
# Processed and saved augmented (color): 320_0_color.jpg
# Processed and saved original: 320_1.jpg
# Processed and saved augmented (flipped): 320_1_flipped.jpg
# Processed and saved augmented (rotated): 320_1_rotated.jpg
# Processed and saved augmented (color): 320_1_color.jpg
# Processed and saved original: 325_0.jpg
# Processed and saved augmented (flipped): 325_0_flipped.jpg
# Processed and saved augmented (rotated): 325_0_rotated.jpg
# Processed and saved augmented (color): 325_0_color.jpg
# Processed and saved original: 325_1.jpg
# Processed and saved augmented (flipped): 325_1_flipped.jpg
# Processed and saved augmented (rotated): 325_1_rotated.jpg
# Processed and saved augmented (color): 325_1_color.jpg
# Processed and saved original: 325_2.jpg
# Processed and saved augmented (flipped): 325_2_flipped.jpg
# Processed and saved augmented (rotated): 325_2_rotated.jpg
# Processed and saved augmented (color): 325_2_color.jpg
# Processed and saved original: 325_3.jpg
# Processed and saved augmented (flipped): 325_3_flipped.jpg
# Processed and saved augmented (rotated): 325_3_rotated.jpg
# Processed and saved augmented (color): 325_3_color.jpg
# Processed and saved original: 327_0.jpg
# Processed and saved augmented (flipped): 327_0_flipped.jpg
# Processed and saved augmented (rotated): 327_0_rotated.jpg
# Processed and saved augmented (color): 327_0_color.jpg
# Processed and saved original: 328_0.jpg
# Processed and saved augmented (flipped): 328_0_flipped.jpg
# Processed and saved augmented (rotated): 328_0_rotated.jpg
# Processed and saved augmented (color): 328_0_color.jpg
# Processed and saved augmented (flipped): 325_3_flipped.jpg
# Processed and saved augmented (rotated): 325_3_rotated.jpg
# Processed and saved augmented (color): 325_3_color.jpg
# Processed and saved original: 327_0.jpg
# Processed and saved augmented (flipped): 327_0_flipped.jpg
# Processed and saved augmented (rotated): 327_0_rotated.jpg
# Processed and saved augmented (color): 327_0_color.jpg
# Processed and saved original: 328_0.jpg
# Processed and saved augmented (flipped): 328_0_flipped.jpg
# Processed and saved augmented (rotated): 328_0_rotated.jpg
# Processed and saved augmented (color): 328_0_color.jpg
# Processed and saved original: 328_1.jpg
# Processed and saved augmented (flipped): 328_1_flipped.jpg
# Processed and saved augmented (rotated): 328_1_rotated.jpg
# Processed and saved augmented (color): 328_1_color.jpg
# Processed and saved original: 329_0.jpg
# Processed and saved augmented (flipped): 329_0_flipped.jpg
# Processed and saved augmented (rotated): 329_0_rotated.jpg
# Processed and saved augmented (color): 329_0_color.jpg
# Processed and saved original: 330_0.jpg
# Processed and saved augmented (flipped): 330_0_flipped.jpg
# Processed and saved augmented (rotated): 330_0_rotated.jpg
# Processed and saved augmented (color): 330_0_color.jpg
# Processed and saved original: 330_1.jpg
# Processed and saved augmented (flipped): 330_1_flipped.jpg
# Processed and saved augmented (rotated): 330_1_rotated.jpg
# Processed and saved original: 328_1.jpg
# Processed and saved augmented (flipped): 328_1_flipped.jpg
# Processed and saved augmented (rotated): 328_1_rotated.jpg
# Processed and saved augmented (color): 328_1_color.jpg
# Processed and saved original: 329_0.jpg
# Processed and saved augmented (flipped): 329_0_flipped.jpg
# Processed and saved augmented (rotated): 329_0_rotated.jpg
# Processed and saved augmented (color): 329_0_color.jpg
# Processed and saved original: 330_0.jpg
# Processed and saved augmented (flipped): 330_0_flipped.jpg
# Processed and saved augmented (rotated): 330_0_rotated.jpg
# Processed and saved augmented (color): 330_0_color.jpg
# Processed and saved original: 330_1.jpg
# Processed and saved augmented (flipped): 330_1_flipped.jpg
# Processed and saved augmented (rotated): 330_1_rotated.jpg
# Processed and saved augmented (color): 330_1_color.jpg
# Processed and saved original: 330_2.jpg
# Processed and saved augmented (flipped): 330_2_flipped.jpg
# Processed and saved augmented (rotated): 330_2_rotated.jpg
# Processed and saved augmented (color): 330_2_color.jpg
# Processed and saved original: 331_0.jpg
# Processed and saved augmented (flipped): 331_0_flipped.jpg
# Processed and saved augmented (rotated): 331_0_rotated.jpg
# Processed and saved augmented (color): 331_0_color.jpg
# Processed and saved original: 332_0.jpg
# Processed and saved augmented (flipped): 332_0_flipped.jpg
# Processed and saved augmented (rotated): 332_0_rotated.jpg
# Processed and saved augmented (color): 332_0_color.jpg
# Processed and saved original: 332_1.jpg
# Processed and saved augmented (flipped): 332_1_flipped.jpg
# Processed and saved augmented (rotated): 332_1_rotated.jpg
# Processed and saved augmented (color): 332_1_color.jpg
# Processed and saved original: 336_0.jpg
# Processed and saved augmented (flipped): 336_0_flipped.jpg
# Processed and saved augmented (color): 330_1_color.jpg
# Processed and saved original: 330_2.jpg
# Processed and saved augmented (flipped): 330_2_flipped.jpg
# Processed and saved augmented (rotated): 330_2_rotated.jpg
# Processed and saved augmented (color): 330_2_color.jpg
# Processed and saved original: 331_0.jpg
# Processed and saved augmented (flipped): 331_0_flipped.jpg
# Processed and saved augmented (rotated): 331_0_rotated.jpg
# Processed and saved augmented (color): 331_0_color.jpg
# Processed and saved original: 332_0.jpg
# Processed and saved augmented (flipped): 332_0_flipped.jpg
# Processed and saved augmented (rotated): 332_0_rotated.jpg
# Processed and saved augmented (color): 332_0_color.jpg
# Processed and saved original: 332_1.jpg
# Processed and saved augmented (flipped): 332_1_flipped.jpg
# Processed and saved augmented (rotated): 332_1_rotated.jpg
# Processed and saved augmented (color): 332_1_color.jpg
# Processed and saved original: 336_0.jpg
# Processed and saved augmented (flipped): 336_0_flipped.jpg
# Processed and saved augmented (rotated): 336_0_rotated.jpg
# Processed and saved augmented (color): 336_0_color.jpg
# Processed and saved original: 336_1.jpg
# Processed and saved augmented (flipped): 336_1_flipped.jpg
# Processed and saved augmented (rotated): 336_1_rotated.jpg
# Processed and saved augmented (color): 336_1_color.jpg
# Processed and saved original: 336_2.jpg
# Processed and saved augmented (flipped): 336_2_flipped.jpg
# Processed and saved augmented (rotated): 336_2_rotated.jpg
# Processed and saved augmented (color): 336_2_color.jpg
# Processed and saved original: 336_3.jpg
# Processed and saved augmented (flipped): 336_3_flipped.jpg
# Processed and saved augmented (rotated): 336_3_rotated.jpg
# Processed and saved augmented (color): 336_3_color.jpg
# Processed and saved original: 338_0.jpg
# Processed and saved augmented (flipped): 338_0_flipped.jpg
# Processed and saved augmented (rotated): 336_0_rotated.jpg
# Processed and saved augmented (color): 336_0_color.jpg
# Processed and saved original: 336_1.jpg
# Processed and saved augmented (flipped): 336_1_flipped.jpg
# Processed and saved augmented (rotated): 336_1_rotated.jpg
# Processed and saved augmented (color): 336_1_color.jpg
# Processed and saved original: 336_2.jpg
# Processed and saved augmented (flipped): 336_2_flipped.jpg
# Processed and saved augmented (rotated): 336_2_rotated.jpg
# Processed and saved augmented (color): 336_2_color.jpg
# Processed and saved original: 336_3.jpg
# Processed and saved augmented (flipped): 336_3_flipped.jpg
# Processed and saved augmented (rotated): 336_3_rotated.jpg
# Processed and saved augmented (color): 336_3_color.jpg
# Processed and saved original: 338_0.jpg
# Processed and saved augmented (flipped): 338_0_flipped.jpg
# Processed and saved augmented (rotated): 338_0_rotated.jpg
# Processed and saved augmented (color): 338_0_color.jpg
# Processed and saved original: 338_1.jpg
# Processed and saved augmented (flipped): 338_1_flipped.jpg
# Processed and saved augmented (rotated): 338_1_rotated.jpg
# Processed and saved augmented (color): 338_1_color.jpg
# Processed and saved original: 341_0.jpg
# Processed and saved augmented (flipped): 341_0_flipped.jpg
# Processed and saved augmented (rotated): 341_0_rotated.jpg
# Processed and saved augmented (color): 341_0_color.jpg
# Processed and saved augmented (rotated): 338_0_rotated.jpg
# Processed and saved augmented (color): 338_0_color.jpg
# Processed and saved original: 338_1.jpg
# Processed and saved augmented (flipped): 338_1_flipped.jpg
# Processed and saved augmented (rotated): 338_1_rotated.jpg
# Processed and saved augmented (color): 338_1_color.jpg
# Processed and saved original: 341_0.jpg
# Processed and saved augmented (flipped): 341_0_flipped.jpg
# Processed and saved augmented (rotated): 341_0_rotated.jpg
# Processed and saved augmented (color): 341_0_color.jpg
# Processed and saved original: 343_0.jpg
# Processed and saved augmented (flipped): 343_0_flipped.jpg
# Processed and saved augmented (rotated): 343_0_rotated.jpg
# Processed and saved augmented (color): 343_0_color.jpg
# Processed and saved original: 343_1.jpg
# Processed and saved augmented (flipped): 343_1_flipped.jpg
# Processed and saved augmented (rotated): 343_1_rotated.jpg
# Processed and saved augmented (color): 343_1_color.jpg
# Processed and saved original: 345_0.jpg
# Processed and saved augmented (flipped): 345_0_flipped.jpg
# Processed and saved augmented (rotated): 345_0_rotated.jpg
# Processed and saved augmented (color): 345_0_color.jpg
# Processed and saved original: 345_1.jpg
# Processed and saved augmented (flipped): 345_1_flipped.jpg
# Processed and saved augmented (rotated): 345_1_rotated.jpg
# Processed and saved augmented (color): 345_1_color.jpg
# Processed and saved original: 345_2.jpg
# Processed and saved augmented (flipped): 345_2_flipped.jpg
# Processed and saved augmented (rotated): 345_2_rotated.jpg
# Processed and saved augmented (color): 345_2_color.jpg
# Processed and saved original: 345_3.jpg
# Processed and saved augmented (flipped): 345_3_flipped.jpg
# Processed and saved original: 343_0.jpg
# Processed and saved augmented (flipped): 343_0_flipped.jpg
# Processed and saved augmented (rotated): 343_0_rotated.jpg
# Processed and saved augmented (color): 343_0_color.jpg
# Processed and saved original: 343_1.jpg
# Processed and saved augmented (flipped): 343_1_flipped.jpg
# Processed and saved augmented (rotated): 343_1_rotated.jpg
# Processed and saved augmented (color): 343_1_color.jpg
# Processed and saved original: 345_0.jpg
# Processed and saved augmented (flipped): 345_0_flipped.jpg
# Processed and saved augmented (rotated): 345_0_rotated.jpg
# Processed and saved augmented (color): 345_0_color.jpg
# Processed and saved original: 345_1.jpg
# Processed and saved augmented (flipped): 345_1_flipped.jpg
# Processed and saved augmented (rotated): 345_1_rotated.jpg
# Processed and saved augmented (color): 345_1_color.jpg
# Processed and saved original: 345_2.jpg
# Processed and saved augmented (flipped): 345_2_flipped.jpg
# Processed and saved augmented (rotated): 345_2_rotated.jpg
# Processed and saved augmented (color): 345_2_color.jpg
# Processed and saved original: 345_3.jpg
# Processed and saved augmented (flipped): 345_3_flipped.jpg
# Processed and saved augmented (rotated): 345_3_rotated.jpg
# Processed and saved augmented (color): 345_3_color.jpg
# Processed and saved original: 346_0.jpg
# Processed and saved augmented (flipped): 346_0_flipped.jpg
# Processed and saved augmented (rotated): 346_0_rotated.jpg
# Processed and saved augmented (color): 346_0_color.jpg
# Processed and saved original: 347_0.jpg
# Processed and saved augmented (flipped): 347_0_flipped.jpg
# Processed and saved augmented (rotated): 347_0_rotated.jpg
# Processed and saved augmented (color): 347_0_color.jpg
# Processed and saved original: 348_0.jpg
# Processed and saved augmented (flipped): 348_0_flipped.jpg
# Processed and saved augmented (rotated): 348_0_rotated.jpg
# Processed and saved augmented (color): 348_0_color.jpg
# Processed and saved original: 348_1.jpg
# Processed and saved augmented (rotated): 345_3_rotated.jpg
# Processed and saved augmented (color): 345_3_color.jpg
# ...
# Processed and saved augmented (color): 14064_2_color.jpg
# Processed and saved original: 14064_3.jpg
# Processed and saved augmented (flipped): 14064_3_flipped.jpg
# Processed and saved augmented (rotated): 14064_3_rotated.jpg
# Processed and saved augmented (color): 14064_3_color.jpg
# Processed and saved original: 14065_0.jpg
# Processed and saved augmented (flipped): 14065_0_flipped.jpg
# Processed and saved augmented (rotated): 14065_0_rotated.jpg
# Processed and saved augmented (color): 14065_0_color.jpg
# Processed and saved original: 14066_0.jpg
# Processed and saved augmented (flipped): 14066_0_flipped.jpg
# Processed and saved augmented (rotated): 14066_0_rotated.jpg
# Processed and saved augmented (color): 14066_0_color.jpg
# Processed and saved original: 14067_0.jpg
# Processed and saved augmented (flipped): 14067_0_flipped.jpg
# Processed and saved augmented (rotated): 14067_0_rotated.jpg
# Processed and saved augmented (color): 14067_0_color.jpg
# Processed and saved original: 14068_0.jpg
# Processed and saved augmented (flipped): 14068_0_flipped.jpg
# Processed and saved augmented (rotated): 14068_0_rotated.jpg
# Processed and saved augmented (color): 14068_0_color.jpg
# Processed and saved original: 14065_0.jpg
# Processed and saved augmented (flipped): 14065_0_flipped.jpg
# Processed and saved augmented (rotated): 14065_0_rotated.jpg
# Processed and saved augmented (color): 14065_0_color.jpg
# Processed and saved original: 14066_0.jpg
# Processed and saved augmented (flipped): 14066_0_flipped.jpg
# Processed and saved augmented (rotated): 14066_0_rotated.jpg
# Processed and saved augmented (color): 14066_0_color.jpg
# Processed and saved original: 14067_0.jpg
# Processed and saved augmented (flipped): 14067_0_flipped.jpg
# Processed and saved augmented (rotated): 14067_0_rotated.jpg
# Processed and saved augmented (color): 14067_0_color.jpg
# Processed and saved original: 14068_0.jpg
# Processed and saved augmented (flipped): 14068_0_flipped.jpg
# Processed and saved augmented (rotated): 14068_0_rotated.jpg
# Processed and saved augmented (color): 14068_0_color.jpg
# Processed and saved original: 14070_0.jpg
# Processed and saved augmented (flipped): 14070_0_flipped.jpg
# Processed and saved augmented (rotated): 14070_0_rotated.jpg
# Processed and saved augmented (color): 14070_0_color.jpg
# Processed and saved original: 14070_1.jpg
# Processed and saved augmented (flipped): 14070_1_flipped.jpg
# Processed and saved augmented (rotated): 14070_1_rotated.jpg
# Processed and saved augmented (color): 14070_1_color.jpg
# Processed and saved original: 14070_2.jpg
# Processed and saved augmented (flipped): 14070_2_flipped.jpg
# Processed and saved augmented (rotated): 14070_2_rotated.jpg
# Processed and saved augmented (color): 14070_2_color.jpg
# Processed and saved original: 14070_3.jpg
# Processed and saved augmented (flipped): 14070_3_flipped.jpg
# Processed and saved original: 14070_0.jpg
# Processed and saved augmented (flipped): 14070_0_flipped.jpg
# Processed and saved augmented (rotated): 14070_0_rotated.jpg
# Processed and saved augmented (color): 14070_0_color.jpg
# Processed and saved original: 14070_1.jpg
# Processed and saved augmented (flipped): 14070_1_flipped.jpg
# Processed and saved augmented (rotated): 14070_1_rotated.jpg
# Processed and saved augmented (color): 14070_1_color.jpg
# Processed and saved original: 14070_2.jpg
# Processed and saved augmented (flipped): 14070_2_flipped.jpg
# Processed and saved augmented (rotated): 14070_2_rotated.jpg
# Processed and saved augmented (color): 14070_2_color.jpg
# Processed and saved original: 14070_3.jpg
# Processed and saved augmented (flipped): 14070_3_flipped.jpg
# Processed and saved augmented (rotated): 14070_3_rotated.jpg
# Processed and saved augmented (color): 14070_3_color.jpg
# Processed and saved original: 14070_4.jpg
# Processed and saved augmented (flipped): 14070_4_flipped.jpg
# Processed and saved augmented (rotated): 14070_4_rotated.jpg
# Processed and saved augmented (color): 14070_4_color.jpg
# Processed and saved original: 14073_0.jpg
# Processed and saved augmented (flipped): 14073_0_flipped.jpg
# Processed and saved augmented (rotated): 14073_0_rotated.jpg
# Processed and saved augmented (color): 14073_0_color.jpg
# Processed and saved original: 14075_0.jpg
# Processed and saved augmented (flipped): 14075_0_flipped.jpg
# Processed and saved augmented (rotated): 14075_0_rotated.jpg
# Processed and saved augmented (color): 14075_0_color.jpg
# Processed and saved original: 14076_0.jpg
# Processed and saved augmented (rotated): 14070_3_rotated.jpg
# Processed and saved augmented (color): 14070_3_color.jpg
# Processed and saved original: 14070_4.jpg
# Processed and saved augmented (flipped): 14070_4_flipped.jpg
# Processed and saved augmented (rotated): 14070_4_rotated.jpg
# Processed and saved augmented (color): 14070_4_color.jpg
# Processed and saved original: 14073_0.jpg
# Processed and saved augmented (flipped): 14073_0_flipped.jpg
# Processed and saved augmented (rotated): 14073_0_rotated.jpg
# Processed and saved augmented (color): 14073_0_color.jpg
# Processed and saved original: 14075_0.jpg
# Processed and saved augmented (flipped): 14075_0_flipped.jpg
# Processed and saved augmented (rotated): 14075_0_rotated.jpg
# Processed and saved augmented (color): 14075_0_color.jpg
# Processed and saved original: 14076_0.jpg
# Processed and saved augmented (flipped): 14076_0_flipped.jpg
# Processed and saved augmented (rotated): 14076_0_rotated.jpg
# Processed and saved augmented (color): 14076_0_color.jpg
# Processed and saved original: 14078_0.jpg
# Processed and saved augmented (flipped): 14078_0_flipped.jpg
# Processed and saved augmented (rotated): 14078_0_rotated.jpg
# Processed and saved augmented (color): 14078_0_color.jpg
# Processed and saved original: 14078_1.jpg
# Processed and saved augmented (flipped): 14078_1_flipped.jpg
# Processed and saved augmented (rotated): 14078_1_rotated.jpg
# Processed and saved augmented (color): 14078_1_color.jpg
# Processed and saved original: 14079_0.jpg
# Processed and saved augmented (flipped): 14079_0_flipped.jpg
# Processed and saved augmented (rotated): 14079_0_rotated.jpg
# Processed and saved augmented (color): 14079_0_color.jpg
# Processed and saved original: 14079_1.jpg
# Processed and saved augmented (flipped): 14079_1_flipped.jpg
# Processed and saved augmented (rotated): 14079_1_rotated.jpg
# Processed and saved augmented (color): 14079_1_color.jpg
# Processed and saved augmented (flipped): 14076_0_flipped.jpg
# Processed and saved augmented (rotated): 14076_0_rotated.jpg
# Processed and saved augmented (color): 14076_0_color.jpg
# Processed and saved original: 14078_0.jpg
# Processed and saved augmented (flipped): 14078_0_flipped.jpg
# Processed and saved augmented (rotated): 14078_0_rotated.jpg
# Processed and saved augmented (color): 14078_0_color.jpg
# Processed and saved original: 14078_1.jpg
# Processed and saved augmented (flipped): 14078_1_flipped.jpg
# Processed and saved augmented (rotated): 14078_1_rotated.jpg
# Processed and saved augmented (color): 14078_1_color.jpg
# Processed and saved original: 14079_0.jpg
# Processed and saved augmented (flipped): 14079_0_flipped.jpg
# Processed and saved augmented (rotated): 14079_0_rotated.jpg
# Processed and saved augmented (color): 14079_0_color.jpg
# Processed and saved original: 14079_1.jpg
# Processed and saved augmented (flipped): 14079_1_flipped.jpg
# Processed and saved augmented (rotated): 14079_1_rotated.jpg
# Processed and saved augmented (color): 14079_1_color.jpg
# Processed and saved original: 14079_2.jpg
# Processed and saved augmented (flipped): 14079_2_flipped.jpg
# Processed and saved augmented (rotated): 14079_2_rotated.jpg
# Processed and saved augmented (color): 14079_2_color.jpg
# Processed and saved original: 14080_0.jpg
# Processed and saved augmented (flipped): 14080_0_flipped.jpg
# Processed and saved augmented (rotated): 14080_0_rotated.jpg
# Processed and saved augmented (color): 14080_0_color.jpg
# Processed and saved original: 14081_0.jpg
# Processed and saved augmented (flipped): 14081_0_flipped.jpg
# Processed and saved augmented (rotated): 14081_0_rotated.jpg
# Processed and saved augmented (color): 14081_0_color.jpg
# Processed and saved original: 14081_1.jpg
# Processed and saved augmented (flipped): 14081_1_flipped.jpg
# Processed and saved original: 14079_2.jpg
# Processed and saved augmented (flipped): 14079_2_flipped.jpg
# Processed and saved augmented (rotated): 14079_2_rotated.jpg
# Processed and saved augmented (color): 14079_2_color.jpg
# Processed and saved original: 14080_0.jpg
# Processed and saved augmented (flipped): 14080_0_flipped.jpg
# Processed and saved augmented (rotated): 14080_0_rotated.jpg
# Processed and saved augmented (color): 14080_0_color.jpg
# Processed and saved original: 14081_0.jpg
# Processed and saved augmented (flipped): 14081_0_flipped.jpg
# Processed and saved augmented (rotated): 14081_0_rotated.jpg
# Processed and saved augmented (color): 14081_0_color.jpg
# Processed and saved original: 14081_1.jpg
# Processed and saved augmented (flipped): 14081_1_flipped.jpg
# Processed and saved augmented (rotated): 14081_1_rotated.jpg
# Processed and saved augmented (color): 14081_1_color.jpg
# Processed and saved original: 14083_0.jpg
# Processed and saved augmented (flipped): 14083_0_flipped.jpg
# Processed and saved augmented (rotated): 14083_0_rotated.jpg
# Processed and saved augmented (color): 14083_0_color.jpg
# Processed and saved original: 14083_1.jpg
# Processed and saved augmented (flipped): 14083_1_flipped.jpg
# Processed and saved augmented (rotated): 14083_1_rotated.jpg
# Processed and saved augmented (color): 14083_1_color.jpg
# Processed and saved original: 14084_0.jpg
# Processed and saved augmented (flipped): 14084_0_flipped.jpg
# Processed and saved augmented (rotated): 14084_0_rotated.jpg
# Processed and saved augmented (color): 14084_0_color.jpg
# Processed and saved original: 14084_1.jpg
# Processed and saved augmented (flipped): 14084_1_flipped.jpg
# Processed and saved augmented (rotated): 14084_1_rotated.jpg
# Processed and saved augmented (color): 14084_1_color.jpg
# Processed and saved original: 14089_0.jpg
# Processed and saved augmented (flipped): 14089_0_flipped.jpg
# Processed and saved augmented (rotated): 14089_0_rotated.jpg
# Processed and saved augmented (color): 14089_0_color.jpg
# Processed and saved original: 14089_1.jpg
# Processed and saved augmented (flipped): 14089_1_flipped.jpg
# Processed and saved augmented (rotated): 14081_1_rotated.jpg
# Processed and saved augmented (color): 14081_1_color.jpg
# Processed and saved original: 14083_0.jpg
# Processed and saved augmented (flipped): 14083_0_flipped.jpg
# Processed and saved augmented (rotated): 14083_0_rotated.jpg
# Processed and saved augmented (color): 14083_0_color.jpg
# Processed and saved original: 14083_1.jpg
# Processed and saved augmented (flipped): 14083_1_flipped.jpg
# Processed and saved augmented (rotated): 14083_1_rotated.jpg
# Processed and saved augmented (color): 14083_1_color.jpg
# Processed and saved original: 14084_0.jpg
# Processed and saved augmented (flipped): 14084_0_flipped.jpg
# Processed and saved augmented (rotated): 14084_0_rotated.jpg
# Processed and saved augmented (color): 14084_0_color.jpg
# Processed and saved original: 14084_1.jpg
# Processed and saved augmented (flipped): 14084_1_flipped.jpg
# Processed and saved augmented (rotated): 14084_1_rotated.jpg
# Processed and saved augmented (color): 14084_1_color.jpg
# Processed and saved original: 14089_0.jpg
# Processed and saved augmented (flipped): 14089_0_flipped.jpg
# Processed and saved augmented (rotated): 14089_0_rotated.jpg
# Processed and saved augmented (color): 14089_0_color.jpg
# Processed and saved original: 14089_1.jpg
# Processed and saved augmented (flipped): 14089_1_flipped.jpg
# Processed and saved augmented (rotated): 14089_1_rotated.jpg
# Processed and saved augmented (color): 14089_1_color.jpg
# Processed and saved original: 14093_0.jpg
# Processed and saved augmented (flipped): 14093_0_flipped.jpg
# Processed and saved augmented (rotated): 14093_0_rotated.jpg
# Processed and saved augmented (color): 14093_0_color.jpg
# Processed and saved original: 14094_0.jpg
# Processed and saved augmented (flipped): 14094_0_flipped.jpg
# Processed and saved augmented (rotated): 14094_0_rotated.jpg
# Processed and saved augmented (color): 14094_0_color.jpg
# Processed and saved original: 14096_0.jpg
# Processed and saved augmented (flipped): 14096_0_flipped.jpg
# Processed and saved augmented (rotated): 14096_0_rotated.jpg
# Processed and saved augmented (color): 14096_0_color.jpg
# Processed and saved original: 14096_1.jpg
# Processed and saved augmented (flipped): 14096_1_flipped.jpg
# Processed and saved augmented (rotated): 14096_1_rotated.jpg
# Processed and saved augmented (rotated): 14089_1_rotated.jpg
# Processed and saved augmented (color): 14089_1_color.jpg
# Processed and saved original: 14093_0.jpg
# Processed and saved augmented (flipped): 14093_0_flipped.jpg
# Processed and saved augmented (rotated): 14093_0_rotated.jpg
# Processed and saved augmented (color): 14093_0_color.jpg
# Processed and saved original: 14094_0.jpg
# Processed and saved augmented (flipped): 14094_0_flipped.jpg
# Processed and saved augmented (rotated): 14094_0_rotated.jpg
# Processed and saved augmented (color): 14094_0_color.jpg
# Processed and saved original: 14096_0.jpg
# Processed and saved augmented (flipped): 14096_0_flipped.jpg
# Processed and saved augmented (rotated): 14096_0_rotated.jpg
# Processed and saved augmented (color): 14096_0_color.jpg
# Processed and saved original: 14096_1.jpg
# Processed and saved augmented (flipped): 14096_1_flipped.jpg
# Processed and saved augmented (rotated): 14096_1_rotated.jpg
# Processed and saved augmented (color): 14096_1_color.jpg
# Processed and saved original: 14098_0.jpg
# Processed and saved augmented (flipped): 14098_0_flipped.jpg
# Processed and saved augmented (rotated): 14098_0_rotated.jpg
# Processed and saved augmented (color): 14098_0_color.jpg
# Processed and saved original: 14098_1.jpg
# Processed and saved augmented (flipped): 14098_1_flipped.jpg
# Processed and saved augmented (rotated): 14098_1_rotated.jpg
# Processed and saved augmented (color): 14098_1_color.jpg
# Processed and saved original: 14098_2.jpg
# Processed and saved augmented (flipped): 14098_2_flipped.jpg
# Processed and saved augmented (rotated): 14098_2_rotated.jpg
# Processed and saved augmented (color): 14098_2_color.jpg
# Processed and saved original: 14102_0.jpg
# Processed and saved augmented (flipped): 14102_0_flipped.jpg
# Processed and saved augmented (color): 14096_1_color.jpg
# Processed and saved original: 14098_0.jpg
# Processed and saved augmented (flipped): 14098_0_flipped.jpg
# Processed and saved augmented (rotated): 14098_0_rotated.jpg
# Processed and saved augmented (color): 14098_0_color.jpg
# Processed and saved original: 14098_1.jpg
# Processed and saved augmented (flipped): 14098_1_flipped.jpg
# Processed and saved augmented (rotated): 14098_1_rotated.jpg
# Processed and saved augmented (color): 14098_1_color.jpg
# Processed and saved original: 14098_2.jpg
# Processed and saved augmented (flipped): 14098_2_flipped.jpg
# Processed and saved augmented (rotated): 14098_2_rotated.jpg
# Processed and saved augmented (color): 14098_2_color.jpg
# Processed and saved original: 14102_0.jpg
# Processed and saved augmented (flipped): 14102_0_flipped.jpg
# Processed and saved augmented (rotated): 14102_0_rotated.jpg
# Processed and saved augmented (color): 14102_0_color.jpg
# Processed and saved original: 14102_1.jpg
# Processed and saved augmented (flipped): 14102_1_flipped.jpg
# Processed and saved augmented (rotated): 14102_1_rotated.jpg
# Processed and saved augmented (color): 14102_1_color.jpg
# Saved new mapping to processed_image_mapping.json
# Image preprocessing and augmentation completed.
# Processed and saved augmented (rotated): 14102_0_rotated.jpg
# Processed and saved augmented (color): 14102_0_color.jpg
# Processed and saved original: 14102_1.jpg
# Processed and saved augmented (flipped): 14102_1_flipped.jpg
# Processed and saved augmented (rotated): 14102_1_rotated.jpg
# Processed and saved augmented (color): 14102_1_color.jpg
# Saved new mapping to processed_image_mapping.json
# Image preprocessing and augmentation completed.
